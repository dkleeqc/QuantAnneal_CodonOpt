# %%
import pygad
import numpy as np

# %%
function_inputs = [4,-2,3.5,5,-11,-4.7]
desired_output = 44

def fitness_func(solution, solution_idx):
    output = numpy.sum(solution*function_inputs)
    fitness = 1.0 / (numpy.abs(output - desired_output) + 0.000001)
    return fitness

fitness_function = fitness_func

# %%
def on_start(ga_instance):
    print("on_start()")

def on_fitness(ga_instance, population_fitness):
    print("on_fitness()")

def on_parents(ga_instance, selected_parents):
    print("on_parents()")

def on_crossover(ga_instance, offspring_crossover):
    print("on_crossover()")

def on_mutation(ga_instance, offspring_mutation):
    print("on_mutation()")

def on_generation(ga_instance):
    print("on_generation()")

def on_stop(ga_instance, last_population_fitness):
    print("on_stop()")

# %%
ga_instance = pygad.GA(num_generations=3,
                       num_parents_mating=5,
                       fitness_func=fitness_function,
                       sol_per_pop=10,
                       num_genes=len(function_inputs),
                       on_start=on_start,
                       on_fitness=on_fitness,
                       on_parents=on_parents,
                       on_crossover=on_crossover,
                       on_mutation=on_mutation,
                       on_generation=on_generation,
                       on_stop=on_stop)

ga_instance.run()
# Out:
# on_start()
# on_fitness()
# on_parents()
# on_crossover()
# on_mutation()
# on_generation()
# on_fitness()
# on_parents()
# on_crossover()
# on_mutation()
# on_generation()
# on_fitness()
# on_parents()
# on_crossover()
# on_mutation()
# on_generation()
# on_stop()

# %% [markdown]
# ## Fitting a Linear Model $y = \vec{w}\cdot \vec{x}$.
# given $\vec{x}=(4,-,2,3,5,5,-11,-4.7)$

# %%
"""
Given the following function:
    y = f(w1:w6) = w1x1 + w2x2 + w3x3 + w4x4 + w5x5 + 6wx6
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11,-4.7) and y=44
What are the best values for the 6 weights (w1 to w6)? We are going to use the genetic algorithm to optimize this function.
"""
function_inputs = [4,-2,3.5,5,-11,-4.7] # Function inputs.
desired_output = 44 # Function output.

# %% [markdown]
# fitness_func 은 maximize를  할  수 있도

# %%
def fitness_func(solution, solution_idx):
    # Calculating the fitness value of each solution in the current population.
    # The fitness function calulates the sum of products between each input and its corresponding weight.
    output = numpy.sum(solution*function_inputs)
    fitness = 1.0 / numpy.abs(output - desired_output)
    return fitness

# %%
fitness_function = fitness_func

num_generations = 100 # Number of generations.
num_parents_mating = 7 # Number of solutions to be selected as parents in the mating pool.

# %%
sol_per_pop = 50 # Number of solutions in the population.
num_genes = len(function_inputs)

# %%
init_range_low = -2
init_range_high = 5

# %%
parent_selection_type = "sss" # Type of parent selection.
keep_parents = 7 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

crossover_type = "single_point" # Type of the crossover operator.

# Parameters of the mutation operation.
mutation_type = "random" # Type of the mutation operator.
mutation_percent_genes = 10 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists or when mutation_type is None.

last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# %%
last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       on_generation=callback_generation)
# Out:
# /Users/Mac_dk/anaconda3/envs/bio/lib/python3.9/site-packages/pygad/pygad.py:486: UserWarning: The percentage of genes to mutate (mutation_percent_genes=10) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   if not self.suppress_warnings: warnings.warn("The percentage of genes to mutate (mutation_percent_genes={mutation_percent}) resutled in selecting ({mutation_num}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.".format(mutation_percent=mutation_percent_genes, mutation_num=mutation_num_genes))

# %%
# Running the GA to optimize the parameters of the function.
ga_instance.run()

# After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
ga_instance.plot_result()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

prediction = numpy.sum(numpy.array(function_inputs)*solution)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))
# Out:
# Generation = 1
# Fitness    = 3.0391170875340006
# Change     = 3.0391170875340006
# Generation = 2
# Fitness    = 12.698972792832645
# Change     = 9.659855705298645
# Generation = 3
# Fitness    = 292.56755682415076
# Change     = 279.8685840313181
# Generation = 4
# Fitness    = 513.3522604423001
# Change     = 220.78470361814936
# Generation = 5
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 6
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 7
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 8
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 9
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 10
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 11
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 12
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 13
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 14
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 15
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 16
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 17
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 18
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 19
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 20
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 21
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 22
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 23
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 24
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 25
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 26
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 27
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 28
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 29
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 30
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 31
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 32
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 33
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 34
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 35
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 36
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 37
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 38
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 39
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 40
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 41
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 42
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 43
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 44
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 45
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 46
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 47
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 48
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 49
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 50
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 51
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 52
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 53
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 54
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 55
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 56
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 57
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 58
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 59
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 60
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 61
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 62
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 63
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 64
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 65
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 66
# Fitness    = 513.3522604423001
# Change     = 0.0
# Generation = 67
# Fitness    = 522.6741678388706
# Change     = 9.32190739657051
# Generation = 68
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 69
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 70
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 71
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 72
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 73
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 74
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 75
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 76
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 77
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 78
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 79
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 80
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 81
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 82
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 83
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 84
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 85
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 86
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 87
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 88
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 89
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 90
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 91
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 92
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 93
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 94
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 95
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 96
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 97
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 98
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 99
# Fitness    = 522.6741678388706
# Change     = 0.0
# Generation = 100
# Fitness    = 522.6741678388706
# Change     = 0.0
# /Users/Mac_dk/anaconda3/envs/bio/lib/python3.9/site-packages/pygad/pygad.py:3135: UserWarning: Please use the plot_fitness() method instead of plot_result(). The plot_result() method will be removed in the future.
#   warnings.warn("Please use the plot_fitness() method instead of plot_result(). The plot_result() method will be removed in the future.")
# Parameters of the best solution : [ 4.98626596  3.45704436  1.71807422  3.63322169 -0.87651213  0.6063965 ]
# Fitness value of the best solution = 522.6741678388706
# Index of the best solution : 0
# Predicted output based on the best solution : 44.001913237847845
# Best fitness value reached after 67 generations.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
import pygad
import numpy

function_inputs = [4,-2,3.5,5,-11,-4.7] # Function inputs.
desired_output = 44 # Function output.

def fitness_func(solution, solution_idx):
    # Calculating the fitness value of each solution in the current population.
    # The fitness function calulates the sum of products between each input and its corresponding weight.
    output = numpy.sum(solution*function_inputs)
    fitness = 1.0 / numpy.abs(output - desired_output)
    return fitness

fitness_function = fitness_func

num_generations = 100 # Number of generations.
num_parents_mating = 7 # Number of solutions to be selected as parents in the mating pool.

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter. This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters. If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
sol_per_pop = 50 # Number of solutions in the population.
num_genes = len(function_inputs)

init_range_low = -2
init_range_high = 5

parent_selection_type = "sss" # Type of parent selection.
keep_parents = 7 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

crossover_type = "single_point" # Type of the crossover operator.

# Parameters of the mutation operation.
mutation_type = "random" # Type of the mutation operator.
mutation_percent_genes = 10 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists or when mutation_type is None.

last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       on_generation=callback_generation)

# Running the GA to optimize the parameters of the function.
ga_instance.run()

# After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
ga_instance.plot_result()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

prediction = numpy.sum(numpy.array(function_inputs)*solution)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# Saving the GA instance.
filename = 'genetic' # The filename to which the instance is saved. The name is without extension.
ga_instance.save(filename=filename)
# Loading the saved GA instance.
loaded_ga_instance = pygad.load(filename=filename)
loaded_ga_instance.run()
loaded_ga_instance.plot_result()
solution, solution_fitness, solution_idx = loaded_ga_instance.best_solution()
solution
# Out:
# Generation = 1
# Fitness    = 2.5264509470270906
# Change     = 2.5264509470270906
# Generation = 2
# Fitness    = 13.588884488793202
# Change     = 11.062433541766111
# Generation = 3
# Fitness    = 13.588884488793202
# Change     = 0.0
# Generation = 4
# Fitness    = 22.39115903258143
# Change     = 8.80227454378823
# Generation = 5
# Fitness    = 22.39115903258143
# Change     = 0.0
# Generation = 6
# Fitness    = 22.39115903258143
# Change     = 0.0
# Generation = 7
# Fitness    = 150.9929239284257
# Change     = 128.60176489584427
# Generation = 8
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 9
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 10
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 11
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 12
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 13
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 14
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 15
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 16
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 17
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 18
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 19
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 20
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 21
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 22
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 23
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 24
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 25
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 26
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 27
# Fitness    = 150.9929239284257
# Change     = 0.0
# Generation = 28
# Fitness    = 162.2105502733269
# Change     = 11.217626344901191
# Generation = 29
# Fitness    = 162.2105502733269
# Change     = 0.0
# Generation = 30
# Fitness    = 162.2105502733269
# Change     = 0.0
# Generation = 31
# Fitness    = 280.6601794662273
# Change     = 118.4496291929004
# Generation = 32
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 33
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 34
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 35
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 36
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 37
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 38
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 39
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 40
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 41
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 42
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 43
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 44
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 45
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 46
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 47
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 48
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 49
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 50
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 51
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 52
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 53
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 54
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 55
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 56
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 57
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 58
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 59
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 60
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 61
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 62
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 63
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 64
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 65
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 66
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 67
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 68
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 69
# Fitness    = 280.6601794662273
# Change     = 0.0
# Generation = 70
# Fitness    = 411.20902934251365
# Change     = 130.54884987628634
# Generation = 71
# Fitness    = 411.20902934251365
# Change     = 0.0
# Generation = 72
# Fitness    = 411.20902934251365
# Change     = 0.0
# Generation = 73
# Fitness    = 411.20902934251365
# Change     = 0.0
# Generation = 74
# Fitness    = 411.20902934251365
# Change     = 0.0
# Generation = 75
# Fitness    = 411.20902934251365
# Change     = 0.0
# Generation = 76
# Fitness    = 411.20902934251365
# Change     = 0.0
# Generation = 77
# Fitness    = 532.8746477714393
# Change     = 121.66561842892565
# Generation = 78
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 79
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 80
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 81
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 82
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 83
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 84
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 85
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 86
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 87
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 88
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 89
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 90
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 91
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 92
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 93
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 94
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 95
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 96
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 97
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 98
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 99
# Fitness    = 532.8746477714393
# Change     = 0.0
# Generation = 100
# Fitness    = 532.8746477714393
# Change     = 0.0
# Parameters of the best solution : [ 4.06887899 -0.01116484  0.55507354 -0.93942533 -1.97927563 -1.84816347]
# Fitness value of the best solution = 532.8746477714393
# Index of the best solution : 0
# Predicted output based on the best solution : 44.00187661395449
# Best fitness value reached after 77 generations.
# Generation = 1
# Fitness    = 2145.292105071843
# Change     = 1612.4174573004034
# Generation = 2
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 3
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 4
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 5
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 6
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 7
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 8
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 9
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 10
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 11
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 12
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 13
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 14
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 15
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 16
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 17
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 18
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 19
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 20
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 21
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 22
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 23
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 24
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 25
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 26
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 27
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 28
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 29
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 30
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 31
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 32
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 33
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 34
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 35
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 36
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 37
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 38
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 39
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 40
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 41
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 42
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 43
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 44
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 45
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 46
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 47
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 48
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 49
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 50
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 51
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 52
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 53
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 54
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 55
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 56
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 57
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 58
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 59
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 60
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 61
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 62
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 63
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 64
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 65
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 66
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 67
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 68
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 69
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 70
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 71
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 72
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 73
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 74
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 75
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 76
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 77
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 78
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 79
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 80
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 81
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 82
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 83
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 84
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 85
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 86
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 87
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 88
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 89
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 90
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 91
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 92
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 93
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 94
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 95
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 96
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 97
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 98
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 99
# Fitness    = 2145.292105071843
# Change     = 0.0
# Generation = 100
# Fitness    = 2145.292105071843
# Change     = 0.0
# array([ 4.07494201, -0.00704133,  0.19034022,  1.37391986, -1.04213861,
#        -1.84816347])
